# %%
# !pip install opencv-python
# !pip install imutils
import argparse
import imutils
import numpy as np
import cv2
import os, shutil
from PIL import Image
from matplotlib.pyplot import imsave
import matplotlib.pyplot as plt
import imghdr

#Defining data that we are going to use
or_dir = 'Data/case_9_kesz_marc/'  #original directory for images
le = len(os.listdir(or_dir))       #number of elements in the original directory
li = os.listdir(or_dir)            #elements in original directory
li2 = []
for i in li:
    if 'jpg' in  i:
        li2.append(i)
        
nam_num = 0
#This part we deal with files extenstions because they are in the same directory
for i in li2:   #list of original pics
    im_nam = i.split(".")
    nam = im_nam [0]
    for j in li:                    #list of every file in the dir
        im_nam2 = j.split(".")      #main name of file
        if nam in im_nam2[0]:  
            if 'png' in im_nam2:
                im_nam2_num = 0
                for el in li:       #list of every file in the dir 
                    if (im_nam2[0] in el):
                        print(el)
                        img = 'Data/case_9_kesz_marc/' + el 
                        print(type(img))
                        im = cv2.imread(img)
                        gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
                        blurred = cv2.GaussianBlur(gray, (5, 5), 0)
                        thresh = cv2.threshold(blurred, 60, 255, cv2.THRESH_BINARY_INV)[1]
                        cnts = cv2.findContours(thresh, cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)
                        cnts = imutils.grab_contours(cnts)
                        na = 0 
                        for c in range(0,len(cnts)):
                            cnt = cnts[c]
                            M = cv2.moments(cnt)
                            cx = int(M['m10']/M['m00'])
                            cy = int(M['m01']/M['m00'])
                            imag_jpg = 'Data/case_9_kesz_marc/' + nam +'.jpg'
                            imag_png = 'Data/case_9_kesz_marc/' + im_nam2[0] + '.png'
                            print(type(imag_jpg))
                            print(type(imag_png))
                            image_jpg = cv2.imread(imag_jpg)
                            image_png = cv2.imread(imag_png)
                            y1 = cx-100
                            y2 = cx+100
                            x1 = cy-100
                            x2 = cy+100
                            if x2 > 2000:
                                x2 = 2000
                                x1 = 1800
                            if y2 > 2000:
                                y2 = 2000 
                                y1 = 1800
                            if x1 < 0:
                                x1 = 0
                                x2 = 200
                            if y1 <0:
                                y1 = 0
                                y2 = 200
                        
                            crop_imag_jpg = image_jpg[x1:x2, y1:y2].copy()
                            crop_imag_png = image_png[x1:x2, y1:y2].copy()
                            
                            ima_name_jpg = 'Data/Train data/Labels/'+ nam +str(nam_num)+'_'+str(im_nam2_num)+'_'+str(na)+'.jpg' 
                            ima_name_png = 'Data/Train data/Mask/'+ nam +str(nam_num)+'_'+str(im_nam2_num)+'_'+str(na)+'.png'
                            
                            cv2.imwrite(ima_name_jpg,crop_imag_jpg)
                            cv2.imwrite(ima_name_png,crop_imag_png)
                            na = na +1 
                    im_nam2_num = im_nam2_num + 1
    nam_num = nam_num + 1                     
                            
                            
                            
                            
                            
                            
                            

#file formatting 
# for i in range (0,le):
#     a  = li[i]
#     image_in_splits = a.split(".");
#     fileFormat = image_in_splits[len(image_in_splits) - 1];
#     print(fileFormat)
# Out:
# Requirement already satisfied: opencv-python in c:\users\khand\anaconda3\envs\tensorflow-gpu\lib\site-packages (4.2.0.32)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\khand\anaconda3\envs\tensorflow-gpu\lib\site-packages (from opencv-python) (1.18.1)
# Requirement already satisfied: imutils in c:\users\khand\anaconda3\envs\tensorflow-gpu\lib\site-packages (0.5.3)
# case_9-134000-12000-136000-14000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-12000-136000-14000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-14000-136000-16000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-18000-136000-20000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-20000-136000-22000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-20000-136000-22000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-22000-136000-24000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-24000-136000-26000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-24000-136000-26000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-52000-136000-54000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-56000-136000-58000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-58000-136000-60000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-58000-136000-60000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-60000-136000-62000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-64000-136000-66000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-66000-136000-68000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-68000-136000-70000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-134000-68000-136000-70000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-10000-138000-12000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-14000-138000-16000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-18000-138000-20000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-18000-138000-20000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-20000-138000-22000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-20000-138000-22000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-22000-138000-24000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-24000-138000-26000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-26000-138000-28000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-26000-138000-28000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-54000-138000-56000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-62000-138000-64000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-64000-138000-66000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-66000-138000-68000-1-100-S_1.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# case_9-136000-66000-138000-68000-1-100-S_2.png
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-07a48bd7917a> in <module>
#      51                             print(type(imag_jpg))
#      52                             print(type(imag_png))
# ---> 53                             image_jpg = cv2.imread(imag_jpg)
#      54                             image_png = cv2.imread(imag_png)
#      55                             y1 = cx-100
#
# KeyboardInterrupt:
